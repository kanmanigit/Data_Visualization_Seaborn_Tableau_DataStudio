# %%
# Searborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("pre_placement.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
# Number of Rows and Columns

dataset.shape
# Out:
# (215, 15)

# %%
# Number of Rows and Columns

print("No of Rows",dataset.shape[0])
print("No of Columns",dataset.shape[1])
# Out:
# No of Rows 215
# No of Columns 15

# %% [markdown]
#  # Univariant Analysis
#  ## Histogram

# %%
import seaborn as sb
sb.distplot(dataset['ssc_p'],kde=True)
# Out:
# /var/folders/1s/70xy4dvs6mn0zqfz6nvhbypw0000gn/T/ipykernel_10407/999875533.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(dataset['ssc_p'],kde=True)
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %% [markdown]
# ## Bivariant Analysis: Distribution  (Histogram + Scatter plot)

# %%
sb.jointplot(data=dataset,x='ssc_p',y='salary')
plt.show()

# %%
# Heat map

sb.jointplot(data=dataset,x='ssc_p',y='salary',kind='hex')
plt.show()

# %%
sb.jointplot(data=dataset,x='ssc_p',y='salary',kind='kde')
plt.show()

# %%
# Pair plot

# %%
sb.pairplot(data=dataset,kind="scatter",diag_kind='kde',hue='gender',palette='husl')
plt.show()

# %% [markdown]
# # Categorical plot
# ## Stripplot......X axis-categorical data, y axis= Quantitative data

# %%
sb.stripplot(data=dataset,x='ssc_b',y='ssc_p',hue='gender')
plt.show()

# %%
sb.stripplot(data=dataset,x='gender',y='ssc_p',jitter=True)

#Amount of jitter (only along the categorical axis) to apply. This
#    can be useful when you have many points and they overlap, so that
#    it is easier to see the distribution. You can specify the amount
#    of jitter (half the width of the uniform random variable support),
#    or use `True` for a good default.
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %% [markdown]
# # Swarmplot

# %%
sb.swarmplot(data=dataset,x='gender',y='ssc_p',hue='status')
plt.show()

# %% [markdown]
# # Distribution Observation- Violin plot

# %%
sb.violinplot(dataset,x='ssc_p')
plt.show()

# %%
sb.violinplot(data=dataset,x='gender',y='salary',hue='gender',palette='husl')
# Out:
# <Axes: xlabel='gender', ylabel='salary'>

# %% [markdown]
# # Box Plot: depicting group of numerical data through Quartiles

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p         salary gender  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.000000      M
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.000000      M
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.000000      M
# 3      4.0  56.00  52.00     52.00     66.0  59.43  288655.405405      M
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.000000      M
# ..     ...    ...    ...       ...      ...    ...            ...    ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.000000      M
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.000000      M
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.000000      M
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.000000      F
# 214  215.0  62.00  58.00     53.00     89.0  60.22  288655.405405      M
#
#        ssc_b    hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
sb.boxplot(data=dataset,x='ssc_b',y='ssc_p', hue='gender',palette='husl')
plt.show()

# %% [markdown]
# Here is the information for the "Others" category in SSC board:
# For Male
# Minimum Marks : 48
# 25th Percentile (Quartile): 62
# Median (50th Percentile): 66
# 75th Percentile (Quartile): 77
# max:99
# For Female
# Minimum Marks : 45
# 25th Percentile (Quartile): 65
# Median (50th Percentile): 74
# 75th Percentile (Quartile): 79
# max-87
#
# Females outperform males consistently across the quartiles, especially at the median (8 points higher), indicating stronger average performance.
# Males have a higher maximum score, meaning the top-performing student is male, despite females generally performing better across most percentiles.
#
# Here is the information for the "central" category in SSC board:
# For Male
# Minimum Marks : 43
# 25th Percentile (Quartile): 59
# Median (50th Percentile): 65
# 75th Percentile (Quartile): 73
# max:87
# For Female
# Minimum Marks : 44
# 25th Percentile (Quartile): 61
# Median (50th Percentile): 68
# 75th Percentile (Quartile): 75
# max:88
#
# Females outperform males across all percentiles, with higher minimum, quartile, and maximum scores.

# %% [markdown]
# # Bar Plot

# %%
sb.barplot(data=dataset,x='ssc_b',y='ssc_p', hue='gender', palette='PuRd')
plt.legend()
plt.show()

# %% [markdown]
# # Count Plot

# %%
sb.countplot(data=dataset,x='ssc_b',hue='gender')
plt.show()

# %%
sb.pointplot(data=dataset,x='degree_t',y='ssc_p')
# Out:
# <Axes: xlabel='degree_t', ylabel='ssc_p'>

# %% [markdown]
# The points represent the values for each group, and the lines connecting them help visualize the trends between categories.

# %% [markdown]
# # Catplot (former factor plot), which creates count plot, box, swarm, Strip plot, Barplot, violin plots..shows the relationship betn numerical and one or more categorical

# %% [markdown]
# ## Count plot

# %%
sb.catplot(data=dataset,x='degree_t',kind='count',hue='gender')

# %% [markdown]
# ## Violin Plot

# %%
dataset=sb.load_dataset("exercise")
dataset
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sb.catplot(data=dataset,x='time',y='pulse',kind='violin',hue='kind',col='diet')

# %% [markdown]
# ## Swarm plot

# %%
sb.catplot(data=dataset,x='degree_t',y='ssc_p',kind='swarm',hue='gender')

# %% [markdown]
# ## Boxplot

# %%
sb.catplot(data=dataset,x='degree_t',y='ssc_p',kind='box',hue='gender')

# %% [markdown]
# ## Bar plot

# %%
sb.catplot(data=dataset,x='degree_t',y='ssc_p',kind='bar',hue='gender')

# %% [markdown]
# ## Strip plot

# %%
sb.catplot(data=dataset,x='degree_t',y='ssc_p',hue='gender')
